# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraKarim23/Association-Rule-Mining-using-Apriori-Algorithm-for-Market-basket-Analysis/blob/main/Association_Rule_Mining_using_Apriori_Algorithm_for_Market_basket_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load Datsets

# %%
dataset = [['Milk','Onion','Nutmeg','Kidney Beans','Eggs','Yogurt'],
           ['Oil','Onion','Nutmeg','Kidney Beans','Eggs','Yogurt'],
           ['Milk','Apple','Kidney Beans','Eggs'],
           ['Milk','Unicorn','Corn','Kidney Beans','Yogurt'],
           ['Corn','Onion','Nutmeg','Kidney Beans','Ice Cream','Eggs']]

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# # Print Datasets

# %%
dataset
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Oil', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Corn', 'Onion', 'Nutmeg', 'Kidney Beans', 'Ice Cream', 'Eggs']]

# %% [markdown]
# # Fit the Datasets

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)

# %%
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Apple   Corn   Eggs  Ice Cream  ...    Oil  Onion  Unicorn  Yogurt
# 0  False  False   True      False  ...  False   True    False    True
# 1  False  False   True      False  ...   True   True    False    True
# 2   True  False   True      False  ...  False  False    False   False
# 3  False   True  False      False  ...  False  False     True    True
# 4  False   True   True       True  ...  False   True    False   False
#
# [5 rows x 11 columns]

# %% [markdown]
# # Import Apriori

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df, min_support=0.6,use_colnames=True)
frequent_itemsets
# Out:
#     support                             itemsets
# 0       0.8                               (Eggs)
# 1       1.0                       (Kidney Beans)
# 2       0.6                               (Milk)
# 3       0.6                             (Nutmeg)
# 4       0.6                              (Onion)
# 5       0.6                             (Yogurt)
# 6       0.8                 (Eggs, Kidney Beans)
# 7       0.6                       (Eggs, Nutmeg)
# 8       0.6                        (Eggs, Onion)
# 9       0.6                 (Kidney Beans, Milk)
# 10      0.6               (Kidney Beans, Nutmeg)
# 11      0.6                (Kidney Beans, Onion)
# 12      0.6               (Yogurt, Kidney Beans)
# 13      0.6                      (Nutmeg, Onion)
# 14      0.6         (Eggs, Kidney Beans, Nutmeg)
# 15      0.6          (Eggs, Kidney Beans, Onion)
# 16      0.6                (Eggs, Nutmeg, Onion)
# 17      0.6        (Kidney Beans, Nutmeg, Onion)
# ...

# %% [markdown]
# # Association Rule Mining

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
res
# Out:
#                       antecedents  ... conviction
# 0                          (Eggs)  ...        inf
# 1                  (Kidney Beans)  ...        1.0
# 2                          (Eggs)  ...        1.6
# 3                        (Nutmeg)  ...        inf
# 4                          (Eggs)  ...        1.6
# 5                         (Onion)  ...        inf
# 6                          (Milk)  ...        inf
# 7                        (Nutmeg)  ...        inf
# 8                         (Onion)  ...        inf
# 9                        (Yogurt)  ...        inf
# 10                       (Nutmeg)  ...        inf
# 11                        (Onion)  ...        inf
# 12           (Eggs, Kidney Beans)  ...        1.6
# 13                 (Eggs, Nutmeg)  ...        inf
# 14         (Kidney Beans, Nutmeg)  ...        inf
# 15                         (Eggs)  ...        1.6
# 16                       (Nutmeg)  ...        inf
# 17           (Eggs, Kidney Beans)  ...        1.6
# ...

# %% [markdown]
# # New Dataframe

# %%
res1 = res[['antecedents','consequents', 'support', 'confidence','lift']]
res1
# Out:
#                       antecedents  ...      lift
# 0                          (Eggs)  ...  1.000000
# 1                  (Kidney Beans)  ...  1.000000
# 2                          (Eggs)  ...  1.250000
# 3                        (Nutmeg)  ...  1.250000
# 4                          (Eggs)  ...  1.250000
# 5                         (Onion)  ...  1.250000
# 6                          (Milk)  ...  1.000000
# 7                        (Nutmeg)  ...  1.000000
# 8                         (Onion)  ...  1.000000
# 9                        (Yogurt)  ...  1.000000
# 10                       (Nutmeg)  ...  1.666667
# 11                        (Onion)  ...  1.666667
# 12           (Eggs, Kidney Beans)  ...  1.250000
# 13                 (Eggs, Nutmeg)  ...  1.000000
# 14         (Kidney Beans, Nutmeg)  ...  1.250000
# 15                         (Eggs)  ...  1.250000
# 16                       (Nutmeg)  ...  1.250000
# 17           (Eggs, Kidney Beans)  ...  1.250000
# ...

# %%
res2 = res1[res1['confidence']>=1]
res2
# Out:
#                       antecedents  ...      lift
# 0                          (Eggs)  ...  1.000000
# 3                        (Nutmeg)  ...  1.250000
# 5                         (Onion)  ...  1.250000
# 6                          (Milk)  ...  1.000000
# 7                        (Nutmeg)  ...  1.000000
# 8                         (Onion)  ...  1.000000
# 9                        (Yogurt)  ...  1.000000
# 10                       (Nutmeg)  ...  1.666667
# 11                        (Onion)  ...  1.666667
# 13                 (Eggs, Nutmeg)  ...  1.000000
# 14         (Kidney Beans, Nutmeg)  ...  1.250000
# 16                       (Nutmeg)  ...  1.250000
# 18                  (Eggs, Onion)  ...  1.000000
# 19          (Kidney Beans, Onion)  ...  1.250000
# 21                        (Onion)  ...  1.250000
# 22                 (Eggs, Nutmeg)  ...  1.666667
# 23                  (Eggs, Onion)  ...  1.666667
# 24                (Onion, Nutmeg)  ...  1.250000
# ...
